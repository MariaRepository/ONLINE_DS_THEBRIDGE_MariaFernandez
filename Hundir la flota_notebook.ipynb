# %%
# Hundir la flota
import numpy as np

# Solicito al usuario el largo y ancho del tablero
#largo = int(input("De cuántas casillas de largo quieres el tablero: \n"))
#ancho = int(input("DE qué ancho?: \n"))

# Función que crea el tablero
def crear_tablero(largo,ancho):
    tablero = np.full((largo,ancho), " ")
    return tablero
    
tablero_resultante = crear_tablero(10,10)
print(tablero_resultante)
# Out:
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']]

# %%
# Las coordenadas nos vienen dadas:
coordenadas_1 = [(0,1), (1,1)]
coordenadas_2 = [(1,3), (1,4), (1,5), (1,6)]    
#tablero_resultante[coordenadas[1]]="O"
#tablero_resultante

barcos_en_tablero = coordenadas_1 + coordenadas_2


for x,y in barcos_en_tablero:
    tablero_resultante[x,y]="0"
    
tablero_resultante
# Out:
# array([[' ', '0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', '0', ' ', '0', '0', '0', '0', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']], dtype='<U1')

# %%
# Se recibe un disparo

coordenadas_disparo=[(0,1)]

for x,y in coordenadas_disparo:
    tablero_resultante[x,y] = "X"

tablero_resultante
# Out:
# array([[' ', 'X', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', '0', ' ', '0', '0', '0', '0', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']], dtype='<U1')

# %%
# Se falla y se hace "agua"

coordenadas_agua=[(4,4)]

for x,y in coordenadas_agua:
    tablero_resultante[x,y] = "-"

tablero_resultante
# Out:
# array([[' ', 'X', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', '0', ' ', '0', '0', '0', '0', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', '-', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']], dtype='<U1')

# %%
# Posicionar 1 barco de 4 posiciones de manera aleatoria

import random

# Inputs coordenadas:
coord_x = np.random.randint(0,10,1)
coord_y = np.random.randint(0,10,1)

coordenadas_aleatorias = np.concatenate((coord_x,coord_y)) # uno los arrays para formar las coord.
print(coordenadas_aleatorias)


# Input orientación: "N": arriba (restar); "S": abajo(sumar); "E":derecha(sumar); "O": izquierda(restar)

orientación = np.random.choice(("N","S","E","O"))
print(orientación)

# Tamaño del barco
tamaño = 4

condicion = True
contador = 1

while condicion == True and contador <= tamaño:

    # Empiezo con el programa
    for x in coordenadas_aleatorias:
        x,y = coordenadas_aleatorias # Saco las coordenadas por separado 
        contador += 1
        if orientación.lower() == "n": # Condicional para la orientación
            variable_y_N = [] # Variable que recogerá los valores de "Y" en función de la orientación
            for i in range(tamaño): # Utilizo el tamaño del barco para regular el nº de veces que se va a ejecutar el bucle
                coord_random_finales = [] # Lista vacía que albergará las coordenadas finales
                incremento = y - i # obtengo los valores de "Y"
                if incremento < 0 or incremento > 9: # Filtro para que no se salga del tablero
                    print("Lo siento pero las coordenadas se salen del tablero")
                    condicion = False
                    break
                else:
                    variable_y_N.append(incremento) # Voy metiendo los valores de "y" generados

            coordenadas_finales = [(x,y) for y in variable_y_N] # finalmente, junto el valor de "x" con los de "y" creando /
                                                                # las coordenadas finales.


        elif orientación.lower() == "s": # Cada bloque siguiente es igual que el anterior variando si suma o resta y la "x", "y"
            variable_y_S = []
            for i in range(tamaño):
                incremento = y + i
                if incremento < 0 or incremento > 9:
                    print("Lo siento pero las coordenadas se salen del tablero")
                    condicion = False
                    break
                else:
                    variable_y_S.append(incremento)

            coordenadas_finales = [(x,y) for y in variable_y_S]   
            #print("Sur, suma", y, variable_y_S)

        elif orientación.lower() == "e":
            variable_x_E = []
            for i in range(tamaño):
                incremento = x + i
                if incremento < 0 or incremento > 9:
                    print("Lo siento pero las coordenadas se salen del tablero")
                    condicion = False
                    break
                else:
                    variable_x_E.append(incremento)

            coordenadas_finales = [(x,y) for y in variable_x_E]    

            #print("Este, suma",x, variable_x_E)    

        else:
            variable_x_O = []
            for i in range(tamaño):
                incremento = x - i
                if incremento < 0 or incremento > 9:
                    print("Lo siento pero las coordenadas se salen del tablero")
                    condicion = False
                    break
                else:
                    variable_x_O.append(incremento)

            coordenadas_finales = [(x,y) for y in variable_x_O]    

            #print("Oeste, resta",x, variable_x_O)

            #coordenadas_finales = [(x,y) for y in variable_y_N]
            #coordenadas_finales = [(x,y) for y in variable_y_S]
            #coordenadas_finales = [(x,y) for y in variable_y_E]
            #coordenadas_finales = [(x,y) for y in variable_y_O]

    print(coordenadas_finales)   

    if any(coordenadas_finales) in barcos_en_tablero: # Hago la última comprobación si las coordenadas ya están ocupadas por los barcos
        print("Lo siento, pero no se puede posicionar en las coordenadas ",x,y,"dado que ya hay un barco")
        condicion = False
        break
    else:
        for x,y in coordenadas_finales: # Si todo está correcto, se muestra en el tablero el barco creado de forma aleatoria
            if len(coordenadas_finales) == tamaño:
                tablero_resultante[x,y] = "O"
            else: 
                print("Prueba otra vez")

tablero_resultante
# Out:
# [5 0]
# N
# Lo siento pero las coordenadas se salen del tablero
# Lo siento pero las coordenadas se salen del tablero
# [(5, 0)]
# Prueba otra vez
# array([[' ', 'X', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', '0', ' ', '0', '0', '0', '0', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', '-', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']], dtype='<U1')

# %%
# Funciones
coordenadas_funciones = [] # Lista de tuplas con las coordenadas a posicionar
tablero_funciones = [] # Contiene el tablero según las dimensiones seleccionadas
todas_coordenadas = [] # Contiene el total de posiciones; todas las coordenadas de barcos y agua


# Solicito al usuario el largo y ancho del tablero
#largo = int(input("De cuántas casillas de largo quieres el tablero: \n"))
#ancho = int(input("DE qué ancho?: \n"))

# Función que crea el tablero
def crear_tablero(largo,ancho):
    tablero = np.full((largo,ancho), " ")
    return tablero

# Se recibe un disparo
coordenadas_disparo=[(0,1)] #Coordenadas de ejemplo

def disparo(coordenadas_disparo):
    todas_coordenadas.extend(coordenadas_disparo)
    if tablero_funciones[coordenadas_disparo]="O":
        print("Tocado")
        tablero_funciones[coordenadas_disparo]="X"
    else:
        print("Agua")
        tablero_funciones[coordenadas_disparo]="-"
    
    
# Función para posicionar los barcos
def poscionar_barcos(coordenadas_funciones):
    for x,y in coordenadas_funciones:
        if any(x,y) in otros_barcos: # Hago la última comprobación si las coordenadas ya están ocupadas por los barcos
            print("Lo siento, pero no se puede posicionar en las coordenadas ",x,y,"dado que ya hay un barco")
        else:
            x,y = coordenadas_funciones
            coordenadas_finales = []
            if orientación.lower() == "n":
                norte(x,y,tamaño) #Llamo a la función norte
            elif orientación.lower() == "s":
                sur(x,y,tamaño) #Llamo a la función sur
            elif orientación.lower() == "e":
                este(x,y,tamaño) #llamo a la función este
            else: 
                oeste(x,y,tamaño) #Por eliminación llamo a la función oeste
                    
    barco_posicionado(coordenadas_finales,barcos_tablero)  #Llamo a la función de barco posicionado

    return tablero_resultante        

# Verifica si las coordenadas que se han dado, ya están ocupadas
def coordenadas_ya_ocupadas(x,y): 
    for x,y in coordenadas_funciones:
        if any(x,y) in otros_barcos: # Hago la última comprobación si las coordenadas ya están ocupadas por los barcos
            print("Lo siento, pero no se puede posicionar en las coordenadas ",x,y,"dado que ya hay un barco")
        else:
            x,y = coordenadas_funciones
    
    

# Función para modificar las coordenadas según orientación
def este(x,y,tamaño):
    variable_x_E = []
    for i in range(tamaño):
        incremento = x + i
        if incremento < 0 or incremento > 9:
            print("Lo siento pero las coordenadas se salen del tablero")
            #condicion = False
            #break
        else:
            variable_x_E.append(incremento)

    coordenadas_finales = [(x,y) for y in variable_x_E] 
    return coordenadas_finales


# Función para modificar las coordenadas según orientación
def oeste(x,y,tamaño):
    variable_x_O = []
        for i in range(tamaño):
            incremento = x - i
            if incremento < 0 or incremento > 9:
                print("Lo siento pero las coordenadas se salen del tablero")
                #condicion = False
                #break
            else:
                variable_x_O.append(incremento)

    coordenadas_finales = [(x,y) for y in variable_x_O]  
    return coordenadas_finales



# Función para modificar las coordenadas según orientación
def norte(x,y,tamaño):
    variable_y_N = [] # Variable que recogerá los valores de "Y" en función de la orientación
    for i in range(tamaño): # Utilizo el tamaño del barco para regular el nº de veces que se va a ejecutar el bucle
        coord_random_finales = [] # Lista vacía que albergará las coordenadas finales
        incremento = y - i # obtengo los valores de "Y"
        if incremento < 0 or incremento > 9: # Filtro para que no se salga del tablero
            print("Lo siento pero las coordenadas se salen del tablero")
            #condicion = False
            #break
        else:
            variable_y_N.append(incremento) # Voy metiendo los valores de "y" generados

    coordenadas_finales = [(x,y) for y in variable_y_N] # finalmente, junto el valor de "x" con los de "y" creando.
    return coordenadas_finales
    
# Función para modificar las coordenadas según orientación
def sur(x,y,tamaño):
    variable_y_S = []
    for i in range(tamaño):
        incremento = y + i
        if incremento < 0 or incremento > 9:
            print("Lo siento pero las coordenadas se salen del tablero")
            #condicion = False
            #break
        else:
            variable_y_S.append(incremento)

    coordenadas_finales = [(x,y) for y in variable_y_S] 
    return coordenadas_finales

# Función para saber si ya hay un barco poscicionado en esas coordenadas
def barco_posicionado(coordenadas_finales,barcos_tablero)
    if any(coordenadas_finales) in barcos_en_tablero: # Hago la última comprobación si las coordenadas ya están ocupadas por los barcos
        print("Lo siento, pero no se puede posicionar en las coordenadas ",x,y,"dado que ya hay un barco")
        #condicion = False
        #break
    else:
        for x,y in coordenadas_finales: # Si todo está correcto, se muestra en el tablero el barco creado de forma aleatoria
            if len(coordenadas_finales) == tamaño:
                    tablero_resultante[x,y] = "O"
        else: 
            print("Prueba otra vez")
    return coordenadas_finales

tablero_resultante
